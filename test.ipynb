# %%
from model import *
from utils import *
from settings import *
# Out:
# Using TensorFlow backend.

# %%
input_size = (32, 32, 3)
model = build_networks('densenet', num_classes=10, input_size=input_size)

# %%
model.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x2110aefc348>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x21140839d08>,
#  <keras.layers.convolutional.Conv2D at 0x2110aefcd08>,
#  <keras.layers.normalization.BatchNormalization at 0x2110af1d888>,
#  <keras.layers.core.Activation at 0x2110af1d6c8>,
#  <keras.layers.convolutional.ZeroPadding2D at 0x2110af37f48>,
#  <keras.layers.pooling.MaxPooling2D at 0x2110af6b688>,
#  <keras.layers.normalization.BatchNormalization at 0x2110b0a9dc8>,
#  <keras.layers.core.Activation at 0x2110b0a9408>,
#  <keras.layers.convolutional.Conv2D at 0x2110b0ae988>,
#  <keras.layers.normalization.BatchNormalization at 0x2110b0df708>,
#  <keras.layers.core.Activation at 0x2110b0cf208>,
#  <keras.layers.convolutional.Conv2D at 0x2110b0e5a48>,
#  <keras.layers.merge.Concatenate at 0x2110b102d88>,
#  <keras.layers.normalization.BatchNormalization at 0x2110b102bc8>,
#  <keras.layers.core.Activation at 0x2110b102b08>,
#  <keras.layers.convolutional.Conv2D at 0x2110b10db88>,
#  <keras.layers.normalization.BatchNormalization at 0x2110b137e08>,
#  <keras.layers.core.Activation at 0x2110b137cc8>,
#  <keras.layers.convolutional.Conv2D at 0x2110b143e48>,
#  <keras.layers.merge.Concatenate at 0x2110b171f88>,
#  <keras.layers.normalization.BatchNormalization at 0x2110b175ec8>,
#  <keras.layers.core.Activation at 0x2110b171f08>,
#  <keras.layers.convolutional.Conv2D at 0x2110b188408>,
#  <keras.layers.normalization.BatchNormalization at 0x2110b1a8b88>,
#  <keras.layers.core.Activation at 0x2110b1a8dc8>,
#  <keras.layers.convolutional.Conv2D at 0x2110b1bff08>,
#  <keras.layers.merge.Concatenate at 0x2110b1dfd08>,
#  <keras.layers.normalization.BatchNormalization at 0x2110b1ea5c8>,
#  <keras.layers.core.Activation at 0x2110b1df808>,
#  <keras.layers.convolutional.Conv2D at 0x2110b1f6848>,
#  <keras.layers.normalization.BatchNormalization at 0x2110b214ec8>,
#  <keras.layers.core.Activation at 0x2110b214e08>,
#  <keras.layers.convolutional.Conv2D at 0x2110b22dec8>,
#  <keras.layers.merge.Concatenate at 0x2110b24cc08>,
#  <keras.layers.normalization.BatchNormalization at 0x2110b24cb08>,
#  <keras.layers.core.Activation at 0x2110b264ac8>,
#  <keras.layers.convolutional.Conv2D at 0x2110b254a48>,
#  <keras.layers.normalization.BatchNormalization at 0x2110b282148>,
#  <keras.layers.core.Activation at 0x2110b282a08>,
#  <keras.layers.convolutional.Conv2D at 0x2110b29cd48>,
#  <keras.layers.merge.Concatenate at 0x2110b2b5f48>,
#  <keras.layers.normalization.BatchNormalization at 0x2110b2c0888>,
#  <keras.layers.core.Activation at 0x2110b2bc648>,
#  <keras.layers.convolutional.Conv2D at 0x2110b2d51c8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110b2f2d48>,
#  <keras.layers.core.Activation at 0x2110b2f2f88>,
#  <keras.layers.convolutional.Conv2D at 0x2110b309ec8>,
#  <keras.layers.merge.Concatenate at 0x2110b327bc8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110b32ce48>,
#  <keras.layers.core.Activation at 0x2110b3402c8>,
#  <keras.layers.convolutional.Conv2D at 0x2110b3406c8>,
#  <keras.layers.pooling.AveragePooling2D at 0x2110b360f48>,
#  <keras.layers.normalization.BatchNormalization at 0x2110b378808>,
#  <keras.layers.core.Activation at 0x2110b378d48>,
#  <keras.layers.convolutional.Conv2D at 0x2110b379808>,
#  <keras.layers.normalization.BatchNormalization at 0x2110b394f48>,
#  <keras.layers.core.Activation at 0x2110b3a9c88>,
#  <keras.layers.convolutional.Conv2D at 0x2110b397888>,
#  <keras.layers.merge.Concatenate at 0x2110b3cbfc8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110b3cbe08>,
#  <keras.layers.core.Activation at 0x2110b3cbd48>,
#  <keras.layers.convolutional.Conv2D at 0x2110b3e6288>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c3d7408>,
#  <keras.layers.core.Activation at 0x2110c3d7d08>,
#  <keras.layers.convolutional.Conv2D at 0x2110c3edec8>,
#  <keras.layers.merge.Concatenate at 0x2110c40b9c8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c414b88>,
#  <keras.layers.core.Activation at 0x2110c40b308>,
#  <keras.layers.convolutional.Conv2D at 0x2110c4244c8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c443a88>,
#  <keras.layers.core.Activation at 0x2110c443948>,
#  <keras.layers.convolutional.Conv2D at 0x2110c45bf88>,
#  <keras.layers.merge.Concatenate at 0x2110c479908>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c4820c8>,
#  <keras.layers.core.Activation at 0x2110c479e48>,
#  <keras.layers.convolutional.Conv2D at 0x2110c490b08>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c4b0e48>,
#  <keras.layers.core.Activation at 0x2110c4c7b48>,
#  <keras.layers.convolutional.Conv2D at 0x2110c4b0e08>,
#  <keras.layers.merge.Concatenate at 0x2110c4e5e88>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c4e5cc8>,
#  <keras.layers.core.Activation at 0x2110c4fda08>,
#  <keras.layers.convolutional.Conv2D at 0x2110c501108>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c520488>,
#  <keras.layers.core.Activation at 0x2110c520c08>,
#  <keras.layers.convolutional.Conv2D at 0x2110c537f08>,
#  <keras.layers.merge.Concatenate at 0x2110c557a48>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c55da48>,
#  <keras.layers.core.Activation at 0x2110c557888>,
#  <keras.layers.convolutional.Conv2D at 0x2110c56f388>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c58d848>,
#  <keras.layers.core.Activation at 0x2110c59e948>,
#  <keras.layers.convolutional.Conv2D at 0x2110c5a4f48>,
#  <keras.layers.merge.Concatenate at 0x2110c5c5d48>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c5c7fc8>,
#  <keras.layers.core.Activation at 0x2110c5c5848>,
#  <keras.layers.convolutional.Conv2D at 0x2110c5dc848>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c5faec8>,
#  <keras.layers.core.Activation at 0x2110c5fae08>,
#  <keras.layers.convolutional.Conv2D at 0x2110c613ec8>,
#  <keras.layers.merge.Concatenate at 0x2110c62dd48>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c62db88>,
#  <keras.layers.core.Activation at 0x2110c649948>,
#  <keras.layers.convolutional.Conv2D at 0x2110c639ac8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c66a208>,
#  <keras.layers.core.Activation at 0x2110c66aac8>,
#  <keras.layers.convolutional.Conv2D at 0x2110c683e08>,
#  <keras.layers.merge.Concatenate at 0x2110aefc048>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c6a40c8>,
#  <keras.layers.core.Activation at 0x2110c6a4788>,
#  <keras.layers.convolutional.Conv2D at 0x2110c6ba248>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c6dadc8>,
#  <keras.layers.core.Activation at 0x2110c6daf88>,
#  <keras.layers.convolutional.Conv2D at 0x2110c6f2f48>,
#  <keras.layers.merge.Concatenate at 0x2110c70ec48>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c712ec8>,
#  <keras.layers.core.Activation at 0x2110c70e748>,
#  <keras.layers.convolutional.Conv2D at 0x2110c726748>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c745dc8>,
#  <keras.layers.core.Activation at 0x2110c745d08>,
#  <keras.layers.convolutional.Conv2D at 0x2110c75ddc8>,
#  <keras.layers.merge.Concatenate at 0x2110c77bb88>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c77ba88>,
#  <keras.layers.core.Activation at 0x2110c794a88>,
#  <keras.layers.convolutional.Conv2D at 0x2110c7849c8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c7b5108>,
#  <keras.layers.core.Activation at 0x2110c7b59c8>,
#  <keras.layers.convolutional.Conv2D at 0x2110c7c1d08>,
#  <keras.layers.merge.Concatenate at 0x2110c7e9fc8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c7f2848>,
#  <keras.layers.core.Activation at 0x2110c7ee4c8>,
#  <keras.layers.convolutional.Conv2D at 0x2110c7f4188>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c823e88>,
#  <keras.layers.core.Activation at 0x2110c823f48>,
#  <keras.layers.convolutional.Conv2D at 0x2110c839e88>,
#  <keras.layers.merge.Concatenate at 0x2110c857408>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c85cdc8>,
#  <keras.layers.core.Activation at 0x2110c871248>,
#  <keras.layers.convolutional.Conv2D at 0x2110c871648>,
#  <keras.layers.pooling.AveragePooling2D at 0x2110c893ec8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c8a97c8>,
#  <keras.layers.core.Activation at 0x2110c8a9cc8>,
#  <keras.layers.convolutional.Conv2D at 0x2110c8ac648>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c8c7f88>,
#  <keras.layers.core.Activation at 0x2110c8ddc48>,
#  <keras.layers.convolutional.Conv2D at 0x2110c8c7ec8>,
#  <keras.layers.merge.Concatenate at 0x2110c8fdf88>,
#  <keras.layers.normalization.BatchNormalization at 0x2110c8fddc8>,
#  <keras.layers.core.Activation at 0x2110c8fdd08>,
#  <keras.layers.convolutional.Conv2D at 0x2110d8e9388>,
#  <keras.layers.normalization.BatchNormalization at 0x2110d907b48>,
#  <keras.layers.core.Activation at 0x2110d907d88>,
#  <keras.layers.convolutional.Conv2D at 0x2110d91fec8>,
#  <keras.layers.merge.Concatenate at 0x2110d93e9c8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110d943b88>,
#  <keras.layers.core.Activation at 0x2110d93e308>,
#  <keras.layers.convolutional.Conv2D at 0x2110d9554c8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110d973a88>,
#  <keras.layers.core.Activation at 0x2110d973948>,
#  <keras.layers.convolutional.Conv2D at 0x2110d98cf88>,
#  <keras.layers.merge.Concatenate at 0x2110d9ab908>,
#  <keras.layers.normalization.BatchNormalization at 0x2110d9b50c8>,
#  <keras.layers.core.Activation at 0x2110d9abe48>,
#  <keras.layers.convolutional.Conv2D at 0x2110d9c3b08>,
#  <keras.layers.normalization.BatchNormalization at 0x2110d9e2e08>,
#  <keras.layers.core.Activation at 0x2110d9f7b88>,
#  <keras.layers.convolutional.Conv2D at 0x2110d9e2e88>,
#  <keras.layers.merge.Concatenate at 0x2110da15ec8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110da15d08>,
#  <keras.layers.core.Activation at 0x2110da15c48>,
#  <keras.layers.convolutional.Conv2D at 0x2110da322c8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110da53a88>,
#  <keras.layers.core.Activation at 0x2110da53cc8>,
#  <keras.layers.convolutional.Conv2D at 0x2110da6bf88>,
#  <keras.layers.merge.Concatenate at 0x2110da85208>,
#  <keras.layers.normalization.BatchNormalization at 0x2110da8eac8>,
#  <keras.layers.core.Activation at 0x2110da85248>,
#  <keras.layers.convolutional.Conv2D at 0x2110da9f408>,
#  <keras.layers.normalization.BatchNormalization at 0x2110dac09c8>,
#  <keras.layers.core.Activation at 0x2110dac0888>,
#  <keras.layers.convolutional.Conv2D at 0x2110dad6ec8>,
#  <keras.layers.merge.Concatenate at 0x2110daf6fc8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110db000c8>,
#  <keras.layers.core.Activation at 0x2110daf6f88>,
#  <keras.layers.convolutional.Conv2D at 0x2110db0fbc8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110db2cf88>,
#  <keras.layers.core.Activation at 0x2110db2cec8>,
#  <keras.layers.convolutional.Conv2D at 0x2110db42a88>,
#  <keras.layers.merge.Concatenate at 0x2110db62e08>,
#  <keras.layers.normalization.BatchNormalization at 0x2110db62c48>,
#  <keras.layers.core.Activation at 0x2110db7b988>,
#  <keras.layers.convolutional.Conv2D at 0x2110db7e088>,
#  <keras.layers.normalization.BatchNormalization at 0x2110db9e9c8>,
#  <keras.layers.core.Activation at 0x2110db9ec08>,
#  <keras.layers.convolutional.Conv2D at 0x2110dbb5ec8>,
#  <keras.layers.merge.Concatenate at 0x2110dbd6148>,
#  <keras.layers.normalization.BatchNormalization at 0x2110dbdaa08>,
#  <keras.layers.core.Activation at 0x2110dbd6188>,
#  <keras.layers.convolutional.Conv2D at 0x2110dbeb348>,
#  <keras.layers.normalization.BatchNormalization at 0x2110dc09908>,
#  <keras.layers.core.Activation at 0x2110dc097c8>,
#  <keras.layers.convolutional.Conv2D at 0x2110dc21f48>,
#  <keras.layers.merge.Concatenate at 0x2110dc41d48>,
#  <keras.layers.normalization.BatchNormalization at 0x2110dc45fc8>,
#  <keras.layers.core.Activation at 0x2110dc41848>,
#  <keras.layers.convolutional.Conv2D at 0x2110dc59848>,
#  <keras.layers.normalization.BatchNormalization at 0x2110dc75ec8>,
#  <keras.layers.core.Activation at 0x2110dc75e08>,
#  <keras.layers.convolutional.Conv2D at 0x2110dc8eec8>,
#  <keras.layers.merge.Concatenate at 0x2110dcadd48>,
#  <keras.layers.normalization.BatchNormalization at 0x2110dcadb88>,
#  <keras.layers.core.Activation at 0x2110dcc5948>,
#  <keras.layers.convolutional.Conv2D at 0x2110dcb5ac8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110dce7208>,
#  <keras.layers.core.Activation at 0x2110dce7ac8>,
#  <keras.layers.convolutional.Conv2D at 0x2110dd00e08>,
#  <keras.layers.merge.Concatenate at 0x2110dd1f948>,
#  <keras.layers.normalization.BatchNormalization at 0x2110dd24948>,
#  <keras.layers.core.Activation at 0x2110dd1f908>,
#  <keras.layers.convolutional.Conv2D at 0x2110dd38288>,
#  <keras.layers.normalization.BatchNormalization at 0x2110dd54fc8>,
#  <keras.layers.core.Activation at 0x2110dd54688>,
#  <keras.layers.convolutional.Conv2D at 0x2110dd6cf88>,
#  <keras.layers.merge.Concatenate at 0x2110dd8be08>,
#  <keras.layers.normalization.BatchNormalization at 0x2110dd90f08>,
#  <keras.layers.core.Activation at 0x2110dd8b788>,
#  <keras.layers.convolutional.Conv2D at 0x2110dda3788>,
#  <keras.layers.normalization.BatchNormalization at 0x2110ddbfe08>,
#  <keras.layers.core.Activation at 0x2110ddbfd48>,
#  <keras.layers.convolutional.Conv2D at 0x2110ddd9e08>,
#  <keras.layers.merge.Concatenate at 0x2110ddf7bc8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110ddf7ac8>,
#  <keras.layers.core.Activation at 0x2110de0fac8>,
#  <keras.layers.convolutional.Conv2D at 0x2110ddffa08>,
#  <keras.layers.normalization.BatchNormalization at 0x2110de32148>,
#  <keras.layers.core.Activation at 0x2110de32a08>,
#  <keras.layers.convolutional.Conv2D at 0x2110de4cd48>,
#  <keras.layers.merge.Concatenate at 0x2110ee33f48>,
#  <keras.layers.normalization.BatchNormalization at 0x2110ee3e888>,
#  <keras.layers.core.Activation at 0x2110ee3b508>,
#  <keras.layers.convolutional.Conv2D at 0x2110ee531c8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110ee6fec8>,
#  <keras.layers.core.Activation at 0x2110ee6ff88>,
#  <keras.layers.convolutional.Conv2D at 0x2110ee87ec8>,
#  <keras.layers.merge.Concatenate at 0x2110eea6d48>,
#  <keras.layers.normalization.BatchNormalization at 0x2110eea9e08>,
#  <keras.layers.core.Activation at 0x2110eea6f48>,
#  <keras.layers.convolutional.Conv2D at 0x2110eec06c8>,
#  <keras.layers.normalization.BatchNormalization at 0x2110eeddd48>,
#  <keras.layers.core.Activation at 0x2110eeddc88>,
#  <keras.layers.convolutional.Conv2D at 0x2110eef2e48>,
#  <keras.layers.merge.Concatenate at 0x2110ef13b08>,
#  <keras.layers.normalization.BatchNormalization at 0x2110ef13f08>,
#  <keras.layers.core.Activation at 0x2110ff2a7c8>,
#  <keras.layers.convolutional.Conv2D at 0x2110ff2aa08>,
#  <keras.layers.normalization.BatchNormalization at 0x2110ff4e088>,
#  <keras.layers.core.Activation at 0x2110ff635c8>,
#  <keras.layers.convolutional.Conv2D at 0x2110ff65c48>,
#  <keras.layers.merge.Concatenate at 0x2110ff80e48>,
#  <keras.layers.normalization.BatchNormalization at 0x2110ff8b788>,
#  <keras.layers.core.Activation at 0x2110ff80f08>,
#  <keras.layers.convolutional.Conv2D at 0x2110ff9e108>,
#  <keras.layers.normalization.BatchNormalization at 0x2110ffbce08>,
#  <keras.layers.core.Activation at 0x2110ffbcec8>,
#  <keras.layers.convolutional.Conv2D at 0x2110ffd4f88>,
#  <keras.layers.merge.Concatenate at 0x2110fff2c88>,
#  <keras.layers.normalization.BatchNormalization at 0x2110fff5d88>,
#  <keras.layers.core.Activation at 0x2110fff2fc8>,
#  <keras.layers.convolutional.Conv2D at 0x2111000b608>,
#  <keras.layers.normalization.BatchNormalization at 0x21110029bc8>,
#  <keras.layers.core.Activation at 0x21110029a88>,
#  <keras.layers.convolutional.Conv2D at 0x21110040f08>,
#  <keras.layers.merge.Concatenate at 0x2111005da48>,
#  <keras.layers.normalization.BatchNormalization at 0x2111005de48>,
#  <keras.layers.core.Activation at 0x21110075708>,
#  <keras.layers.convolutional.Conv2D at 0x21110075ec8>,
#  <keras.layers.normalization.BatchNormalization at 0x21110095f48>,
#  <keras.layers.core.Activation at 0x211100adcc8>,
#  <keras.layers.convolutional.Conv2D at 0x21110098848>,
#  <keras.layers.merge.Concatenate at 0x211100cddc8>,
#  <keras.layers.normalization.BatchNormalization at 0x211100d7708>,
#  <keras.layers.core.Activation at 0x211100cde88>,
#  <keras.layers.convolutional.Conv2D at 0x211100e7048>,
#  <keras.layers.normalization.BatchNormalization at 0x21110106d48>,
#  <keras.layers.core.Activation at 0x21110106e08>,
#  <keras.layers.convolutional.Conv2D at 0x2111011df48>,
#  <keras.layers.merge.Concatenate at 0x2111013cbc8>,
#  <keras.layers.normalization.BatchNormalization at 0x21110140c08>,
#  <keras.layers.core.Activation at 0x2111013c388>,
#  <keras.layers.convolutional.Conv2D at 0x21110153548>,
#  <keras.layers.normalization.BatchNormalization at 0x21110170b08>,
#  <keras.layers.core.Activation at 0x211101709c8>,
#  <keras.layers.convolutional.Conv2D at 0x2111018ae88>,
#  <keras.layers.merge.Concatenate at 0x211101a9988>,
#  <keras.layers.normalization.BatchNormalization at 0x211101b1148>,
#  <keras.layers.core.Activation at 0x211101a9d88>,
#  <keras.layers.convolutional.Conv2D at 0x211101c1c08>,
#  <keras.layers.normalization.BatchNormalization at 0x211101dfe48>,
#  <keras.layers.core.Activation at 0x211101f9c08>,
#  <keras.layers.convolutional.Conv2D at 0x211101dff48>,
#  <keras.layers.merge.Concatenate at 0x21110215f48>,
#  <keras.layers.normalization.BatchNormalization at 0x21110215d88>,
#  <keras.layers.core.Activation at 0x21110215cc8>,
#  <keras.layers.convolutional.Conv2D at 0x21110234348>,
#  <keras.layers.normalization.BatchNormalization at 0x21110254c88>,
#  <keras.layers.core.Activation at 0x21110254d48>,
#  <keras.layers.convolutional.Conv2D at 0x21110269e88>,
#  <keras.layers.merge.Concatenate at 0x21110288b08>,
#  <keras.layers.normalization.BatchNormalization at 0x2111028eb48>,
#  <keras.layers.core.Activation at 0x2111029f088>,
#  <keras.layers.convolutional.Conv2D at 0x2111029f488>,
#  <keras.layers.pooling.AveragePooling2D at 0x211102c0fc8>,
#  <keras.layers.normalization.BatchNormalization at 0x211102d6608>,
#  <keras.layers.core.Activation at 0x211102d6c88>,
#  <keras.layers.convolutional.Conv2D at 0x211102d6f88>,
#  <keras.layers.normalization.BatchNormalization at 0x211102f3f48>,
#  <keras.layers.core.Activation at 0x211102f3e88>,
#  <keras.layers.convolutional.Conv2D at 0x2111030ca48>,
#  <keras.layers.merge.Concatenate at 0x2111032cdc8>,
#  <keras.layers.normalization.BatchNormalization at 0x2111032cc08>,
#  <keras.layers.core.Activation at 0x21110345948>,
#  <keras.layers.convolutional.Conv2D at 0x21110337048>,
#  <keras.layers.normalization.BatchNormalization at 0x21111337b08>,
#  <keras.layers.core.Activation at 0x21111337bc8>,
#  <keras.layers.convolutional.Conv2D at 0x2111134fe88>,
#  <keras.layers.merge.Concatenate at 0x21111369108>,
#  <keras.layers.normalization.BatchNormalization at 0x211113719c8>,
#  <keras.layers.core.Activation at 0x21111369148>,
#  <keras.layers.convolutional.Conv2D at 0x21111384308>,
#  <keras.layers.normalization.BatchNormalization at 0x211113a38c8>,
#  <keras.layers.core.Activation at 0x211113a3788>,
#  <keras.layers.convolutional.Conv2D at 0x211113baf08>,
#  <keras.layers.merge.Concatenate at 0x211113d8e88>,
#  <keras.layers.normalization.BatchNormalization at 0x211113e45c8>,
#  <keras.layers.core.Activation at 0x211113d8808>,
#  <keras.layers.convolutional.Conv2D at 0x211113f1808>,
#  <keras.layers.normalization.BatchNormalization at 0x2111140fe88>,
#  <keras.layers.core.Activation at 0x2111140fdc8>,
#  <keras.layers.convolutional.Conv2D at 0x21111426e88>,
#  <keras.layers.merge.Concatenate at 0x21111448c48>,
#  <keras.layers.normalization.BatchNormalization at 0x21111448b48>,
#  <keras.layers.core.Activation at 0x21111450a88>,
#  <keras.layers.convolutional.Conv2D at 0x2111145f908>,
#  <keras.layers.normalization.BatchNormalization at 0x2111147f1c8>,
#  <keras.layers.core.Activation at 0x2111147fa88>,
#  <keras.layers.convolutional.Conv2D at 0x21111497dc8>,
#  <keras.layers.merge.Concatenate at 0x211114b4fc8>,
#  <keras.layers.normalization.BatchNormalization at 0x211114be908>,
#  <keras.layers.core.Activation at 0x211114b7588>,
#  <keras.layers.convolutional.Conv2D at 0x211114cf248>,
#  <keras.layers.normalization.BatchNormalization at 0x211114eef48>,
#  <keras.layers.core.Activation at 0x211114eef88>,
#  <keras.layers.convolutional.Conv2D at 0x21111506f48>,
#  <keras.layers.merge.Concatenate at 0x21111524dc8>,
#  <keras.layers.normalization.BatchNormalization at 0x21111526ec8>,
#  <keras.layers.core.Activation at 0x21111524748>,
#  <keras.layers.convolutional.Conv2D at 0x2111153c748>,
#  <keras.layers.normalization.BatchNormalization at 0x2111155ad48>,
#  <keras.layers.core.Activation at 0x2111155ac88>,
#  <keras.layers.convolutional.Conv2D at 0x21111572e48>,
#  <keras.layers.merge.Concatenate at 0x21111592a88>,
#  <keras.layers.normalization.BatchNormalization at 0x21111592e88>,
#  <keras.layers.core.Activation at 0x211115a8748>,
#  <keras.layers.convolutional.Conv2D at 0x211115a8f08>,
#  <keras.layers.normalization.BatchNormalization at 0x211115c7fc8>,
#  <keras.layers.core.Activation at 0x211115dfc88>,
#  <keras.layers.convolutional.Conv2D at 0x211115cb848>,
#  <keras.layers.merge.Concatenate at 0x211115fff48>,
#  <keras.layers.normalization.BatchNormalization at 0x211115ffd88>,
#  <keras.layers.core.Activation at 0x211115ffcc8>,
#  <keras.layers.convolutional.Conv2D at 0x2111161a348>,
#  <keras.layers.normalization.BatchNormalization at 0x21111638c08>,
#  <keras.layers.core.Activation at 0x21111638cc8>,
#  <keras.layers.convolutional.Conv2D at 0x21111651f88>,
#  <keras.layers.merge.Concatenate at 0x2111166ea08>,
#  <keras.layers.normalization.BatchNormalization at 0x21111674a08>,
#  <keras.layers.core.Activation at 0x2111166e9c8>,
#  <keras.layers.convolutional.Conv2D at 0x21111685388>,
#  <keras.layers.normalization.BatchNormalization at 0x211116a48c8>,
#  <keras.layers.core.Activation at 0x211116a4788>,
#  <keras.layers.convolutional.Conv2D at 0x211116bdf08>,
#  <keras.layers.merge.Concatenate at 0x211116dee08>,
#  <keras.layers.normalization.BatchNormalization at 0x211116e2f08>,
#  <keras.layers.core.Activation at 0x211116de788>,
#  <keras.layers.convolutional.Conv2D at 0x211116f6788>,
#  <keras.layers.normalization.BatchNormalization at 0x21111712d88>,
#  <keras.layers.core.Activation at 0x21111712cc8>,
#  <keras.layers.convolutional.Conv2D at 0x2111172bd88>,
#  <keras.layers.merge.Concatenate at 0x2111174bac8>,
#  <keras.layers.normalization.BatchNormalization at 0x2111174bec8>,
#  <keras.layers.core.Activation at 0x21111763788>,
#  <keras.layers.convolutional.Conv2D at 0x21111763f48>,
#  <keras.layers.normalization.BatchNormalization at 0x21111781f48>,
#  <keras.layers.core.Activation at 0x21111797cc8>,
#  <keras.layers.convolutional.Conv2D at 0x21111785848>,
#  <keras.layers.merge.Concatenate at 0x211117b8f88>,
#  <keras.layers.normalization.BatchNormalization at 0x211117b8dc8>,
#  <keras.layers.core.Activation at 0x211117b8d08>,
#  <keras.layers.convolutional.Conv2D at 0x211117d2388>,
#  <keras.layers.normalization.BatchNormalization at 0x211117f1c48>,
#  <keras.layers.core.Activation at 0x211117f1d08>,
#  <keras.layers.convolutional.Conv2D at 0x21111808fc8>,
#  <keras.layers.merge.Concatenate at 0x211118291c8>,
#  <keras.layers.normalization.BatchNormalization at 0x2111182fa88>,
#  <keras.layers.core.Activation at 0x21111829208>,
#  <keras.layers.convolutional.Conv2D at 0x211118403c8>,
#  <keras.layers.normalization.BatchNormalization at 0x2111185e908>,
#  <keras.layers.core.Activation at 0x2111185e7c8>,
#  <keras.layers.convolutional.Conv2D at 0x21111875f48>,
#  <keras.layers.merge.Concatenate at 0x21111895f08>,
#  <keras.layers.normalization.BatchNormalization at 0x21111899ec8>,
#  <keras.layers.core.Activation at 0x21111895e88>,
#  <keras.layers.convolutional.Conv2D at 0x211118ae7c8>,
#  <keras.layers.normalization.BatchNormalization at 0x211139dddc8>,
#  <keras.layers.core.Activation at 0x211139ddd08>,
#  <keras.layers.convolutional.Conv2D at 0x211139f5dc8>,
#  <keras.layers.merge.Concatenate at 0x211149e0b08>,
#  <keras.layers.normalization.BatchNormalization at 0x211149e0f08>,
#  <keras.layers.core.Activation at 0x211149f97c8>,
#  <keras.layers.convolutional.Conv2D at 0x211149f9a08>,
#  <keras.layers.normalization.BatchNormalization at 0x21114a1af88>,
#  <keras.layers.core.Activation at 0x21114a33588>,
#  <keras.layers.convolutional.Conv2D at 0x21114a37c08>,
#  <keras.layers.merge.Concatenate at 0x21114a54fc8>,
#  <keras.layers.normalization.BatchNormalization at 0x211102d2cc8>,
#  <keras.layers.core.Activation at 0x21114a68b08>,
#  <keras.layers.pooling.GlobalAveragePooling2D at 0x21114a6d3c8>,
#  <keras.layers.core.Dense at 0x21114a7df48>]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ori_val_acc = 0.556
ori_test_acc = 0.5537

# %% [markdown]
# ### ResNet-20

# %%
x = np.linspace(52, 58)
y = x

# %%
x_impr = [54.6, 55.51, 54.59, 55.84, 54.9]
y_impr_1 = [57.29, 57.17, 56.89, 57.29, 57.74]
y_impr_2 = [57.43, 57.35, 57.34, 56.70, 57.77]
y_impr_3 = [54.60, 56.09, 54.59, 55.84, 55.08]
y_impr_4 = [57.05, 57.38, 56.12, 56.61, 56.87]

x_impr_t = [55.01, 56.12, 54.07, 56.03, 55.93]
y_impr_1t = [57.39, 57.29, 56.37, 56.95, 57.87]
y_impr_2t = [56.29,57.86, 57.07, 56.91, 57.37]
y_impr_3t = [55.01, 56.55, 54.03, 56.03, 55.98]
y_impr_4t = [56.81, 57.11, 57.26, 56.61, 56.48]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(12, 5))
fig.suptitle('ResNet-20', fontsize=20, weight='bold')

ax1.plot(x, y, '-')
ax1.set_title('validation acc.', fontsize=18)
ax1.set_xlabel('original val acc.', fontsize=14)
ax1.set_ylabel('improved val acc.', fontsize=14) 
ax1.plot(x_impr, y_impr_1, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax1.plot(x_impr, y_impr_2, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax1.plot(x_impr, y_impr_3, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax1.plot(x_impr, y_impr_4, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax1.grid(linestyle='--')

ax1.legend()

ax2.plot(x, y, '-')
ax2.set_title('test acc.', fontsize=18)
ax2.set_xlabel('original test acc.', fontsize=14)
ax2.set_ylabel('improved test acc.', fontsize=14) 
ax2.plot(x_impr_t, y_impr_1t, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax2.plot(x_impr_t, y_impr_2t, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax2.plot(x_impr_t, y_impr_3t, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax2.plot(x_impr_t, y_impr_4t, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax2.grid(linestyle='--')

ax2.legend()
plt.savefig("figures/resnet20.jpg",dpi=500,bbox_inches = 'tight')

# %% [markdown]
# ### ResNet-32

# %%
x = np.linspace(52, 58)
y = x

x_impr = [55.6, 54.22, 56.46, 55.32, 54.39]
y_impr_1 = [57.96, 57.99, 58.52, 57.52, 58.29]
y_impr_2 = [57.87, 57.74, 58.69, 58.43, 57.97]
y_impr_3 = [57.58, 56.05, 56.46, 55.32, 55.66]
y_impr_4 = [57.72, 57.03, 59.07, 57.81, 57.13]

x_impr_t = [55.37, 54.59, 56.54, 56.14, 54.48]
y_impr_1t = [57.52, 58.48, 57.58, 58.13, 58.03]
y_impr_2t = [58.53, 57.46, 58.16, 58.00, 57.32]
y_impr_3t = [57.84, 56.21, 56.54, 56.14, 55.52]
y_impr_4t = [57.99, 56.99, 58.56, 58.43, 56.99]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(12, 5))
fig.suptitle('ResNet-32', fontsize=20, weight='bold')

ax1.plot(x, y, '-')
ax1.set_title('validation acc.', fontsize=18)
ax1.set_xlabel('original val acc.', fontsize=14)
ax1.set_ylabel('improved val acc.', fontsize=14) 
ax1.plot(x_impr, y_impr_1, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax1.plot(x_impr, y_impr_2, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax1.plot(x_impr, y_impr_3, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax1.plot(x_impr, y_impr_4, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax1.grid(linestyle='--')

ax1.legend()

ax2.plot(x, y, '-')
ax2.set_title('test acc.', fontsize=18)
ax2.set_xlabel('original test acc.', fontsize=14)
ax2.set_ylabel('improved test acc.', fontsize=14) 
ax2.plot(x_impr_t, y_impr_1t, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax2.plot(x_impr_t, y_impr_2t, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax2.plot(x_impr_t, y_impr_3t, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax2.plot(x_impr_t, y_impr_4t, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax2.grid(linestyle='--')

ax2.legend()
plt.savefig("figures/resnet32.jpg",dpi=500,bbox_inches = 'tight')

# %% [markdown]
# ### MobileNet

# %%
x = np.linspace(34,40)
y = x

x_impr = [35.28, 37.41, 36.49, 36.99, 35.12]
y_impr_1 = np.array([0.3709,0.3957,0.3854,0.3959,0.375])*100
y_impr_2 = np.array([0.3761,0.3963,0.3782,0.39,0.3731])*100
y_impr_3 = np.array([0.3563,0.378,0.3707,0.3808,0.3674])*100
y_impr_4 = np.array([0.376,0.3882,0.3872,0.3897,0.3845])*100

x_impr_t = np.array([0.3644,0.384,0.3675,0.3732,0.3611])*100
y_impr_1t = np.array([0.374,0.4037,0.3822,0.39,0.3785])*100
y_impr_2t = np.array([0.3855,0.4058,0.3761,0.3941,0.3792])*100
y_impr_3t = np.array([0.374,0.3878,0.3743,0.3732,0.3706])*100
y_impr_4t = np.array([0.3826,0.4006,0.382,0.3921,0.3846])*100

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(12, 5))
fig.suptitle('MobileNet', fontsize=20, weight='bold')

ax1.plot(x, y, '-')
ax1.set_title('validation acc.', fontsize=18)
ax1.set_xlabel('original val acc.', fontsize=14)
ax1.set_ylabel('improved val acc.', fontsize=14) 
ax1.plot(x_impr, y_impr_1, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax1.plot(x_impr, y_impr_2, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax1.plot(x_impr, y_impr_3, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax1.plot(x_impr, y_impr_4, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax1.grid(linestyle='--')

ax1.legend()

ax2.plot(x, y, '-')
ax2.set_title('test acc.', fontsize=18)
ax2.set_xlabel('original test acc.', fontsize=14)
ax2.set_ylabel('improved test acc.', fontsize=14) 
ax2.plot(x_impr_t, y_impr_1t, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax2.plot(x_impr_t, y_impr_2t, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax2.plot(x_impr_t, y_impr_3t, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax2.plot(x_impr_t, y_impr_4t, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax2.grid(linestyle='--')

ax2.legend()
plt.savefig("figures/mobilenet.jpg",dpi=500,bbox_inches = 'tight')

# %% [markdown]
# ### MobileNetV2

# %%
x = np.linspace(36,41)
y = x

x_impr = np.array([0.3671 ,0.3757 ,0.3709 ,0.3671 ,0.3693])*100
y_impr_1 = np.array([0.3807 ,0.3910 ,0.3876 ,0.3959 ,0.3917])*100
y_impr_2 = np.array([0.3913 ,0.3960 ,0.4002 ,0.3920 ,0.3977])*100
y_impr_3 = np.array([0.3722 ,0.3821 ,0.3722 ,0.3777 ,0.3772])*100
y_impr_4 = np.array([0.3855 ,0.3876 ,0.3971 ,0.3914 ,0.3889])*100

x_impr_t = np.array([0.3708 ,0.3852 ,0.3734 ,0.3708 ,0.3765])*100
y_impr_1t = np.array([0.3824 ,0.3999 ,0.3868 ,0.3970 ,0.3921])*100
y_impr_2t = np.array([0.3967 ,0.3931 ,0.4023 ,0.3982 ,0.4043])*100
y_impr_3t = np.array([0.3772 ,0.3852 ,0.3815 ,0.3882 ,0.3816])*100
y_impr_4t = np.array([0.3790 ,0.3902 ,0.4039 ,0.3993 ,0.4003])*100

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(12, 5))
fig.suptitle('MobileNetV2', fontsize=20, weight='bold')

ax1.plot(x, y, '-')
ax1.set_title('validation acc.', fontsize=18)
ax1.set_xlabel('original val acc.', fontsize=14)
ax1.set_ylabel('improved val acc.', fontsize=14) 
ax1.plot(x_impr, y_impr_1, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax1.plot(x_impr, y_impr_2, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax1.plot(x_impr, y_impr_3, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax1.plot(x_impr, y_impr_4, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax1.grid(linestyle='--')

ax1.legend()

ax2.plot(x, y, '-')
ax2.set_title('test acc.', fontsize=18)
ax2.set_xlabel('original test acc.', fontsize=14)
ax2.set_ylabel('improved test acc.', fontsize=14) 
ax2.plot(x_impr_t, y_impr_1t, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax2.plot(x_impr_t, y_impr_2t, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax2.plot(x_impr_t, y_impr_3t, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax2.plot(x_impr_t, y_impr_4t, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax2.grid(linestyle='--')

ax2.legend()
plt.savefig("figures/mobilenetv2.jpg",dpi=500,bbox_inches = 'tight')

# %% [markdown]
# ### DenseNet

# %%
x = np.linspace(44,49)
y = x

x_impr = np.array([0.4589,0.4653,0.4557,0.4563,0.4523])*100
y_impr_1 = np.array([0.4746,0.4803,0.4715,0.4826,0.477])*100
y_impr_2 = np.array([0.476,0.4801,0.4719,0.476,0.472])*100
y_impr_3 = np.array([0.4628,0.4653,0.4643,0.4563,0.4523])*100
y_impr_4 = np.array([0.4799,0.4854,0.477,0.4718,0.4724])*100

x_impr_t = np.array([0.4634,0.4623,0.4626,0.4497,0.4605])*100
y_impr_1t = np.array([0.478,0.4794,0.4762,0.4785,0.4779])*100
y_impr_2t = np.array([0.4831,0.4748,0.48,0.4736,0.4809])*100
y_impr_3t = np.array([0.4694,0.4623,0.4673,0.4497,0.4605])*100
y_impr_4t = np.array([0.4852,0.4837,0.4785,0.4841,0.4743])*100

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(12, 5))
fig.suptitle('DenseNet', fontsize=20, weight='bold')

ax1.plot(x, y, '-')
ax1.set_title('validation acc.', fontsize=18)
ax1.set_xlabel('original val acc.', fontsize=14)
ax1.set_ylabel('improved val acc.', fontsize=14) 
ax1.plot(x_impr, y_impr_1, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax1.plot(x_impr, y_impr_2, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax1.plot(x_impr, y_impr_3, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax1.plot(x_impr, y_impr_4, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax1.grid(linestyle='--')

ax1.legend()

ax2.plot(x, y, '-')
ax2.set_title('test acc.', fontsize=18)
ax2.set_xlabel('original test acc.', fontsize=14)
ax2.set_ylabel('improved test acc.', fontsize=14) 
ax2.plot(x_impr_t, y_impr_1t, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax2.plot(x_impr_t, y_impr_2t, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax2.plot(x_impr_t, y_impr_3t, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax2.plot(x_impr_t, y_impr_4t, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax2.grid(linestyle='--')

ax2.legend()
plt.savefig("figures/densenet.jpg",dpi=500,bbox_inches = 'tight')
