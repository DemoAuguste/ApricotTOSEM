# %%
from model import *
from utils import *
from settings import *
# Out:
# Using TensorFlow backend.

# %%
input_size = (32, 32, 3)
model = build_networks('densenet', num_classes=10, input_size=input_size)
# Out:
# WARNING:tensorflow:From D:\research\Anaconda3\envs\deepTest\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
x_train, x_test, y_train, y_test = load_dataset('cifar10')

# %%
pred_y = model.predict(x_train)

# %%
pred_y.shape
# Out:
# (50000, 10)

# %%
pred_y_label = np.argmax(pred_y, axis=1)

# %%
train_y_label = np.argmax(y_train, axis=1)

# %%
pred_y_label.shape
# Out:
# (50000,)

# %%
y_train.shape
# Out:
# (50000, 10)

# %%
z = pred_y_label == train_y_label

# %%
z = np.array(z, dtype=np.int)

# %%
np.sum(z) / 50000
# Out:
# 0.10066

# %%
z2 = z[:, np.newaxis]

# %%
z3 = z2

# %%
z4 = np.concatenate((z2, z3), axis=1)

# %%
z4.shape
# Out:
# (50000, 2)

# %%
len(x_train)
# Out:
# 50000

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ori_val_acc = 0.556
ori_test_acc = 0.5537

# %% [markdown]
# # CIFAR-100

# %% [markdown]
# ### ResNet-20

# %%
x = np.linspace(52, 58)
y = x

# %%
x_impr = [54.6, 55.51, 54.59, 55.84, 54.9]
y_impr_1 = [57.29, 57.17, 56.89, 57.29, 57.74]
y_impr_2 = [57.43, 57.35, 57.34, 56.70, 57.77]
y_impr_3 = [54.60, 56.09, 54.59, 55.84, 55.08]
y_impr_4 = [57.05, 57.38, 56.12, 56.61, 56.87]

x_impr_t = [55.01, 56.12, 54.07, 56.03, 55.93]
y_impr_1t = [57.39, 57.29, 56.37, 56.95, 57.87]
y_impr_2t = [56.29,57.86, 57.07, 56.91, 57.37]
y_impr_3t = [55.01, 56.55, 54.03, 56.03, 55.98]
y_impr_4t = [56.81, 57.11, 57.26, 56.61, 56.48]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(12, 5))
fig.suptitle('ResNet-20', fontsize=20, weight='bold')

ax1.plot(x, y, '-')
ax1.set_title('validation acc.', fontsize=18)
ax1.set_xlabel('original val acc.', fontsize=14)
ax1.set_ylabel('improved val acc.', fontsize=14) 
ax1.plot(x_impr, y_impr_1, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax1.plot(x_impr, y_impr_2, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax1.plot(x_impr, y_impr_3, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax1.plot(x_impr, y_impr_4, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax1.grid(linestyle='--')

ax1.legend()

ax2.plot(x, y, '-')
ax2.set_title('test acc.', fontsize=18)
ax2.set_xlabel('original test acc.', fontsize=14)
ax2.set_ylabel('improved test acc.', fontsize=14) 
ax2.plot(x_impr_t, y_impr_1t, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax2.plot(x_impr_t, y_impr_2t, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax2.plot(x_impr_t, y_impr_3t, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax2.plot(x_impr_t, y_impr_4t, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax2.grid(linestyle='--')

ax2.legend()
plt.savefig("figures/resnet20.jpg",dpi=500,bbox_inches = 'tight')

# %% [markdown]
# ### ResNet-32

# %%
x = np.linspace(52, 58)
y = x

x_impr = [55.6, 54.22, 56.46, 55.32, 54.39]
y_impr_1 = [57.96, 57.99, 58.52, 57.52, 58.29]
y_impr_2 = [57.87, 57.74, 58.69, 58.43, 57.97]
y_impr_3 = [57.58, 56.05, 56.46, 55.32, 55.66]
y_impr_4 = [57.72, 57.03, 59.07, 57.81, 57.13]

x_impr_t = [55.37, 54.59, 56.54, 56.14, 54.48]
y_impr_1t = [57.52, 58.48, 57.58, 58.13, 58.03]
y_impr_2t = [58.53, 57.46, 58.16, 58.00, 57.32]
y_impr_3t = [57.84, 56.21, 56.54, 56.14, 55.52]
y_impr_4t = [57.99, 56.99, 58.56, 58.43, 56.99]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(12, 5))
fig.suptitle('ResNet-32', fontsize=20, weight='bold')

ax1.plot(x, y, '-')
ax1.set_title('validation acc.', fontsize=18)
ax1.set_xlabel('original val acc.', fontsize=14)
ax1.set_ylabel('improved val acc.', fontsize=14) 
ax1.plot(x_impr, y_impr_1, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax1.plot(x_impr, y_impr_2, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax1.plot(x_impr, y_impr_3, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax1.plot(x_impr, y_impr_4, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax1.grid(linestyle='--')

ax1.legend()

ax2.plot(x, y, '-')
ax2.set_title('test acc.', fontsize=18)
ax2.set_xlabel('original test acc.', fontsize=14)
ax2.set_ylabel('improved test acc.', fontsize=14) 
ax2.plot(x_impr_t, y_impr_1t, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax2.plot(x_impr_t, y_impr_2t, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax2.plot(x_impr_t, y_impr_3t, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax2.plot(x_impr_t, y_impr_4t, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax2.grid(linestyle='--')

ax2.legend()
plt.savefig("figures/resnet32.jpg",dpi=500,bbox_inches = 'tight')

# %% [markdown]
# ### MobileNet

# %%
x = np.linspace(34,40)
y = x

x_impr = [35.28, 37.41, 36.49, 36.99, 35.12]
y_impr_1 = np.array([0.3709,0.3957,0.3854,0.3959,0.375])*100
y_impr_2 = np.array([0.3761,0.3963,0.3782,0.39,0.3731])*100
y_impr_3 = np.array([0.3563,0.378,0.3707,0.3808,0.3674])*100
y_impr_4 = np.array([0.376,0.3882,0.3872,0.3897,0.3845])*100

x_impr_t = np.array([0.3644,0.384,0.3675,0.3732,0.3611])*100
y_impr_1t = np.array([0.374,0.4037,0.3822,0.39,0.3785])*100
y_impr_2t = np.array([0.3855,0.4058,0.3761,0.3941,0.3792])*100
y_impr_3t = np.array([0.374,0.3878,0.3743,0.3732,0.3706])*100
y_impr_4t = np.array([0.3826,0.4006,0.382,0.3921,0.3846])*100

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(12, 5))
fig.suptitle('MobileNet', fontsize=20, weight='bold')

ax1.plot(x, y, '-')
ax1.set_title('validation acc.', fontsize=18)
ax1.set_xlabel('original val acc.', fontsize=14)
ax1.set_ylabel('improved val acc.', fontsize=14) 
ax1.plot(x_impr, y_impr_1, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax1.plot(x_impr, y_impr_2, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax1.plot(x_impr, y_impr_3, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax1.plot(x_impr, y_impr_4, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax1.grid(linestyle='--')

ax1.legend()

ax2.plot(x, y, '-')
ax2.set_title('test acc.', fontsize=18)
ax2.set_xlabel('original test acc.', fontsize=14)
ax2.set_ylabel('improved test acc.', fontsize=14) 
ax2.plot(x_impr_t, y_impr_1t, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax2.plot(x_impr_t, y_impr_2t, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax2.plot(x_impr_t, y_impr_3t, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax2.plot(x_impr_t, y_impr_4t, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax2.grid(linestyle='--')

ax2.legend()
plt.savefig("figures/mobilenet.jpg",dpi=500,bbox_inches = 'tight')

# %% [markdown]
# ### MobileNetV2

# %%
x = np.linspace(36,41)
y = x

x_impr = np.array([0.3671 ,0.3757 ,0.3709 ,0.3671 ,0.3693])*100
y_impr_1 = np.array([0.3807 ,0.3910 ,0.3876 ,0.3959 ,0.3917])*100
y_impr_2 = np.array([0.3913 ,0.3960 ,0.4002 ,0.3920 ,0.3977])*100
y_impr_3 = np.array([0.3722 ,0.3821 ,0.3722 ,0.3777 ,0.3772])*100
y_impr_4 = np.array([0.3855 ,0.3876 ,0.3971 ,0.3914 ,0.3889])*100

x_impr_t = np.array([0.3708 ,0.3852 ,0.3734 ,0.3708 ,0.3765])*100
y_impr_1t = np.array([0.3824 ,0.3999 ,0.3868 ,0.3970 ,0.3921])*100
y_impr_2t = np.array([0.3967 ,0.3931 ,0.4023 ,0.3982 ,0.4043])*100
y_impr_3t = np.array([0.3772 ,0.3852 ,0.3815 ,0.3882 ,0.3816])*100
y_impr_4t = np.array([0.3790 ,0.3902 ,0.4039 ,0.3993 ,0.4003])*100

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(12, 5))
fig.suptitle('MobileNetV2', fontsize=20, weight='bold')

ax1.plot(x, y, '-')
ax1.set_title('validation acc.', fontsize=18)
ax1.set_xlabel('original val acc.', fontsize=14)
ax1.set_ylabel('improved val acc.', fontsize=14) 
ax1.plot(x_impr, y_impr_1, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax1.plot(x_impr, y_impr_2, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax1.plot(x_impr, y_impr_3, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax1.plot(x_impr, y_impr_4, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax1.grid(linestyle='--')

ax1.legend()

ax2.plot(x, y, '-')
ax2.set_title('test acc.', fontsize=18)
ax2.set_xlabel('original test acc.', fontsize=14)
ax2.set_ylabel('improved test acc.', fontsize=14) 
ax2.plot(x_impr_t, y_impr_1t, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax2.plot(x_impr_t, y_impr_2t, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax2.plot(x_impr_t, y_impr_3t, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax2.plot(x_impr_t, y_impr_4t, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax2.grid(linestyle='--')

ax2.legend()
plt.savefig("figures/mobilenetv2.jpg",dpi=500,bbox_inches = 'tight')

# %% [markdown]
# ### DenseNet

# %%
x = np.linspace(44,49)
y = x

x_impr = np.array([0.4589,0.4653,0.4557,0.4563,0.4523])*100
y_impr_1 = np.array([0.4746,0.4803,0.4715,0.4826,0.477])*100
y_impr_2 = np.array([0.476,0.4801,0.4719,0.476,0.472])*100
y_impr_3 = np.array([0.4628,0.4653,0.4643,0.4563,0.4523])*100
y_impr_4 = np.array([0.4799,0.4854,0.477,0.4718,0.4724])*100

x_impr_t = np.array([0.4634,0.4623,0.4626,0.4497,0.4605])*100
y_impr_1t = np.array([0.478,0.4794,0.4762,0.4785,0.4779])*100
y_impr_2t = np.array([0.4831,0.4748,0.48,0.4736,0.4809])*100
y_impr_3t = np.array([0.4694,0.4623,0.4673,0.4497,0.4605])*100
y_impr_4t = np.array([0.4852,0.4837,0.4785,0.4841,0.4743])*100

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(12, 5))
fig.suptitle('DenseNet', fontsize=20, weight='bold')

ax1.plot(x, y, '-')
ax1.set_title('validation acc.', fontsize=18)
ax1.set_xlabel('original val acc.', fontsize=14)
ax1.set_ylabel('improved val acc.', fontsize=14) 
ax1.plot(x_impr, y_impr_1, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax1.plot(x_impr, y_impr_2, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax1.plot(x_impr, y_impr_3, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax1.plot(x_impr, y_impr_4, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax1.grid(linestyle='--')

ax1.legend()

ax2.plot(x, y, '-')
ax2.set_title('test acc.', fontsize=18)
ax2.set_xlabel('original test acc.', fontsize=14)
ax2.set_ylabel('improved test acc.', fontsize=14) 
ax2.plot(x_impr_t, y_impr_1t, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax2.plot(x_impr_t, y_impr_2t, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax2.plot(x_impr_t, y_impr_3t, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax2.plot(x_impr_t, y_impr_4t, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax2.grid(linestyle='--')

ax2.legend()
plt.savefig("figures/densenet.jpg",dpi=500,bbox_inches = 'tight')

# %% [markdown]
# # CIFAR-100

# %% [markdown]
# ### ResNet-20

# %%
x = np.linspace(84, 88)
y = x

x_impr = np.array([0.8646,0.8531,0.8566,0.8591,0.8515])*100
y_impr_1 = np.array([0.8768,0.8748,0.8729,0.8764,0.8753])*100
y_impr_2 = np.array([0.8757,0.875,0.8733,0.8749,0.8778])*100
y_impr_3 = np.array([0.8686,0.8531,0.8566,0.8671,0.8469])*100
y_impr_4 = np.array([0.8765,0.8761,0.8736,0.8739,0.8668])*100

x_impr_t = np.array([0.8656,0.8564,0.8571,0.8596,0.8511])*100
y_impr_1t = np.array([0.8739,0.8718,0.8759,0.872,0.8709])*100
y_impr_2t = np.array([0.8753,0.8713,0.8706,0.8732,0.8715])*100
y_impr_3t = np.array([0.8686,0.8564,0.8568,0.8633,0.8508])*100
y_impr_4t = np.array([0.8709,0.8704,0.8778,0.8737,0.8644])*100

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(12, 5))
fig.suptitle('ResNet-20', fontsize=20, weight='bold')

ax1.plot(x, y, '-')
ax1.set_title('validation acc.', fontsize=18)
ax1.set_xlabel('original val acc.', fontsize=14)
ax1.set_ylabel('improved val acc.', fontsize=14) 
ax1.plot(x_impr, y_impr_1, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax1.plot(x_impr, y_impr_2, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax1.plot(x_impr, y_impr_3, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax1.plot(x_impr, y_impr_4, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax1.grid(linestyle='--')

ax1.legend(loc=4)

ax2.plot(x, y, '-')
ax2.set_title('test acc.', fontsize=18)
ax2.set_xlabel('original test acc.', fontsize=14)
ax2.set_ylabel('improved test acc.', fontsize=14) 
ax2.plot(x_impr_t, y_impr_1t, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax2.plot(x_impr_t, y_impr_2t, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax2.plot(x_impr_t, y_impr_3t, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax2.plot(x_impr_t, y_impr_4t, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax2.grid(linestyle='--')

ax2.legend()
plt.savefig("figures/resnet20_cifar100.jpg",dpi=500,bbox_inches = 'tight')

# %% [markdown]
# ### ResNet-32

# %%
x = np.linspace(84, 88)
y = x

x_impr = np.array([0.8706,0.8414,0.8626,0.8657,0.8664])*100
y_impr_1 = np.array([0.883,0.8831,0.885,0.8822,0.8829])*100
y_impr_2 = np.array([0.8829,0.8801,0.88,0.8848,0.8802])*100
y_impr_3 = np.array([0.8794,0.8414,0.8797,0.8679,0.8812])*100
y_impr_4 = np.array([0.8817,0.8813,0.8838,0.8758,0.8754])*100

x_impr_t = np.array([0.8701,0.8407,0.8628,0.8671,0.8691])*100
y_impr_1t = np.array([0.8763,0.8801,0.8809,0.8792,0.8827])*100
y_impr_2t = np.array([0.8798,0.8787,0.8788,0.8818,0.881])*100
y_impr_3t = np.array([0.8718,0.8407,0.8753,0.867,0.8792])*100
y_impr_4t = np.array([0.8797,0.8768,0.8778,0.8775,0.8818])*100

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(12, 5))
fig.suptitle('ResNet-32', fontsize=20, weight='bold')

ax1.plot(x, y, '-')
ax1.set_title('validation acc.', fontsize=18)
ax1.set_xlabel('original val acc.', fontsize=14)
ax1.set_ylabel('improved val acc.', fontsize=14) 
ax1.plot(x_impr, y_impr_1, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax1.plot(x_impr, y_impr_2, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax1.plot(x_impr, y_impr_3, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax1.plot(x_impr, y_impr_4, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax1.grid(linestyle='--')

ax1.legend()

ax2.plot(x, y, '-')
ax2.set_title('test acc.', fontsize=18)
ax2.set_xlabel('original test acc.', fontsize=14)
ax2.set_ylabel('improved test acc.', fontsize=14) 
ax2.plot(x_impr_t, y_impr_1t, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax2.plot(x_impr_t, y_impr_2t, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax2.plot(x_impr_t, y_impr_3t, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax2.plot(x_impr_t, y_impr_4t, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax2.grid(linestyle='--')

ax2.legend()
plt.savefig("figures/resnet32_cifar100.jpg",dpi=500,bbox_inches = 'tight')

# %% [markdown]
# ### MobileNet

# %%
x = np.linspace(74, 78)
y = x

x_impr = np.array([0.7604,0.7588,0.7448,0.7484,0.755])*100
y_impr_1 = np.array([0.7779,0.7818,0.7758,0.7629,0.777])*100
y_impr_2 = np.array([0.7753,0.766,0.7719,0.7589,0.7722])*100
y_impr_3 = np.array([0.7688,0.7588,0.7448,0.7537,0.763])*100
y_impr_4 = np.array([0.7725,0.7758,0.7707,0.768,0.7707])*100

x_impr_t = np.array([0.7649,0.7637,0.7529,0.7484,0.7618])*100
y_impr_1t = np.array([0.778,0.7778,0.7726,0.7614,0.7784])*100
y_impr_2t = np.array([0.7749,0.7727,0.7714,0.7674,0.7715])*100
y_impr_3t = np.array([0.7763,0.7637,0.7529,0.759,0.7692])*100
y_impr_4t = np.array([0.7762,0.7881,0.772,0.763,0.7699])*100

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(12, 5))
fig.suptitle('MobileNet', fontsize=20, weight='bold')

ax1.plot(x, y, '-')
ax1.set_title('validation acc.', fontsize=18)
ax1.set_xlabel('original val acc.', fontsize=14)
ax1.set_ylabel('improved val acc.', fontsize=14) 
ax1.plot(x_impr, y_impr_1, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax1.plot(x_impr, y_impr_2, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax1.plot(x_impr, y_impr_3, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax1.plot(x_impr, y_impr_4, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax1.grid(linestyle='--')

ax1.legend()

ax2.plot(x, y, '-')
ax2.set_title('test acc.', fontsize=18)
ax2.set_xlabel('original test acc.', fontsize=14)
ax2.set_ylabel('improved test acc.', fontsize=14) 
ax2.plot(x_impr_t, y_impr_1t, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax2.plot(x_impr_t, y_impr_2t, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax2.plot(x_impr_t, y_impr_3t, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax2.plot(x_impr_t, y_impr_4t, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax2.grid(linestyle='--')

ax2.legend(loc=4)
plt.savefig("figures/mobilenet_cifar100.jpg",dpi=500,bbox_inches = 'tight')

# %% [markdown]
# ### MobileNetV2

# %%
x = np.linspace(75, 80)
y = x

x_impr = np.array([0.773,0.7547,0.7797,0.7691,0.7577])*100
y_impr_1 = np.array([0.7944,0.772,0.7902,0.7877,0.7835])*100
y_impr_2 = np.array([0.7927,0.7808,0.7892,0.7861,0.7821])*100
y_impr_3 = np.array([0.7731,0.7654,0.7855,0.7657,0.7678])*100
y_impr_4 = np.array([0.7819,0.7754,0.7916,0.7799,0.7767])*100

x_impr_t = np.array([0.7736,0.7658,0.7709,0.7679,0.7709])*100
y_impr_1t = np.array([0.7887,0.7817,0.7842,0.7875,0.7836])*100
y_impr_2t = np.array([0.7948,0.7893,0.789,0.7891,0.7885])*100
y_impr_3t = np.array([0.7764,0.7764,0.7795,0.7679,0.7724])*100
y_impr_4t = np.array([0.7872,0.7842,0.7844,0.7885,0.7871])*100

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(12, 5))
fig.suptitle('MobileNetV2', fontsize=20, weight='bold')

ax1.plot(x, y, '-')
ax1.set_title('validation acc.', fontsize=18)
ax1.set_xlabel('original val acc.', fontsize=14)
ax1.set_ylabel('improved val acc.', fontsize=14) 
ax1.plot(x_impr, y_impr_1, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax1.plot(x_impr, y_impr_2, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax1.plot(x_impr, y_impr_3, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax1.plot(x_impr, y_impr_4, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax1.grid(linestyle='--')

ax1.legend(loc=4)

ax2.plot(x, y, '-')
ax2.set_title('test acc.', fontsize=18)
ax2.set_xlabel('original test acc.', fontsize=14)
ax2.set_ylabel('improved test acc.', fontsize=14) 
ax2.plot(x_impr_t, y_impr_1t, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax2.plot(x_impr_t, y_impr_2t, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax2.plot(x_impr_t, y_impr_3t, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax2.plot(x_impr_t, y_impr_4t, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax2.grid(linestyle='--')

ax2.legend(loc=4)
plt.savefig("figures/mobilenetv2_cifar100.jpg",dpi=500,bbox_inches = 'tight')

# %% [markdown]
# ### DenseNet

# %%
x = np.linspace(79, 82.5)
y = x

x_impr = np.array([0.8081,0.7988,0.8007,0.8079,0.8062])*100
y_impr_1 = np.array([0.8149,0.8057,0.8163,0.8142,0.8147])*100
y_impr_2 = np.array([0.8164,0.8082,0.8175,0.8181,0.8124])*100
y_impr_3 = np.array([0.8111,0.8049,0.8055,0.8158,0.8076])*100
y_impr_4 = np.array([0.814,0.8079,0.8167,0.8146,0.8105])*100

x_impr_t = np.array([0.811,0.8075,0.8046,0.8126,0.8049])*100
y_impr_1t = np.array([0.8183,0.8146,0.8199,0.8159,0.8116])*100
y_impr_2t = np.array([0.8195,0.8174,0.8216,0.8203,0.8142])*100
y_impr_3t = np.array([0.8167,0.8145,0.8111,0.8157,0.8097])*100
y_impr_4t = np.array([0.8151,0.8133,0.8179,0.8135,0.8174])*100

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(12, 5))
fig.suptitle('DenseNet', fontsize=20, weight='bold')

ax1.plot(x, y, '-')
ax1.set_title('validation acc.', fontsize=18)
ax1.set_xlabel('original val acc.', fontsize=14)
ax1.set_ylabel('improved val acc.', fontsize=14) 
ax1.plot(x_impr, y_impr_1, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax1.plot(x_impr, y_impr_2, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax1.plot(x_impr, y_impr_3, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax1.plot(x_impr, y_impr_4, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax1.grid(linestyle='--')

ax1.legend(loc=4)

ax2.plot(x, y, '-')
ax2.set_title('test acc.', fontsize=18)
ax2.set_xlabel('original test acc.', fontsize=14)
ax2.set_ylabel('improved test acc.', fontsize=14) 
ax2.plot(x_impr_t, y_impr_1t, 'D', markersize=10, alpha=0.8, label='Strategy 1')
ax2.plot(x_impr_t, y_impr_2t, 'v', markersize=10, alpha=0.8, label='Strategy 2')
ax2.plot(x_impr_t, y_impr_3t, '*', markersize=10, alpha=0.8, label='Strategy 3')
ax2.plot(x_impr_t, y_impr_4t, 'H', markersize=10, alpha=0.8, label='Strategy 4')
ax2.grid(linestyle='--')

ax2.legend(loc=4)
plt.savefig("figures/densenet_cifar100.jpg",dpi=500,bbox_inches = 'tight')
